# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Using cached pandas-2.2.2-cp39-cp39-win_amd64.whl (11.6 MB)
# Collecting tzdata>=2022.7
#   Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Collecting pytz>=2020.1
#   Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\dharsh\projects\stockastic-main\stock\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting numpy>=1.22.4
#   Using cached numpy-1.26.4-cp39-cp39-win_amd64.whl (15.8 MB)
# Requirement already satisfied: six>=1.5 in c:\dharsh\projects\stockastic-main\stock\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Installing collected packages: pytz, tzdata, numpy, pandas
# Successfully installed numpy-1.26.4 pandas-2.2.2 pytz-2024.1 tzdata-2024.1
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the 'C:\Dharsh\projects\Stockastic-main\stock\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.2.38-py2.py3-none-any.whl (72 kB)
#      ---------------------------------------- 73.0/73.0 KB ? eta 0:00:00
# Collecting frozendict>=2.3.4
#   Downloading frozendict-2.4.3-cp39-cp39-win_amd64.whl (37 kB)
# Collecting appdirs>=1.4.4
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting requests>=2.31
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Collecting lxml>=4.9.1
#   Downloading lxml-5.2.1-cp39-cp39-win_amd64.whl (3.8 MB)
#      ---------------------------------------- 3.8/3.8 MB 8.1 MB/s eta 0:00:00
# Collecting beautifulsoup4>=4.11.1
#   Using cached beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
# Collecting html5lib>=1.1
#   Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
#      -------------------------------------- 112.2/112.2 KB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.3.0 in c:\dharsh\projects\stockastic-main\stock\lib\site-packages (from yfinance) (2.2.2)
# Collecting peewee>=3.16.2
#   Using cached peewee-3.17.3-py3-none-any.whl
# Requirement already satisfied: numpy>=1.16.5 in c:\dharsh\projects\stockastic-main\stock\lib\site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: pytz>=2022.5 in c:\dharsh\projects\stockastic-main\stock\lib\site-packages (from yfinance) (2024.1)
# Collecting multitasking>=0.0.7
#   Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Collecting soupsieve>1.2
#   Using cached soupsieve-2.5-py3-none-any.whl (36 kB)
# Collecting webencodings
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: six>=1.9 in c:\dharsh\projects\stockastic-main\stock\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: tzdata>=2022.7 in c:\dharsh\projects\stockastic-main\stock\lib\site-packages (from pandas>=1.3.0->yfinance) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\dharsh\projects\stockastic-main\stock\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Collecting certifi>=2017.4.17
#   Using cached certifi-2024.2.2-py3-none-any.whl (163 kB)
# Collecting urllib3<3,>=1.21.1
#   Using cached urllib3-2.2.1-py3-none-any.whl (121 kB)
# Collecting charset-normalizer<4,>=2
#   Using cached charset_normalizer-3.3.2-cp39-cp39-win_amd64.whl (100 kB)
# Collecting idna<4,>=2.5
#   Using cached idna-3.7-py3-none-any.whl (66 kB)
# Installing collected packages: webencodings, peewee, multitasking, appdirs, urllib3, soupsieve, lxml, idna, html5lib, frozendict, charset-normalizer, certifi, requests, beautifulsoup4, yfinance
# Successfully installed appdirs-1.4.4 beautifulsoup4-4.12.3 certifi-2024.2.2 charset-normalizer-3.3.2 frozendict-2.4.3 html5lib-1.1 idna-3.7 lxml-5.2.1 multitasking-0.0.11 peewee-3.17.3 requests-2.31.0 soupsieve-2.5 urllib3-2.2.1 webencodings-0.5.1 yfinance-0.2.38
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the 'C:\Dharsh\projects\Stockastic-main\stock\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Import Path from pathlib
from pathlib import Path

# Import yfinance package
import yfinance as yf

# Import pandas package
import pandas as pd

# Import pretty printing
from pprint import pprint

# %%
# Load the data issuers data
issuers = pd.read_csv(Path.cwd().parent / 'data' / 'equity_issuers.csv')

# %%
# View the issuers data -> Issuer Name and Security Id
issuers[['Issuer Name', 'Security Id']].head()
# Out:
#        Issuer Name                        Security Id
# 500002         ABB                  ABB India Limited
# 500003    AEGISLOG               AEGIS LOGISTICS LTD.
# 500008  AMARAJABAT          AMARA RAJA BATTERIES LTD.
# 500009   AMBALALSA  AMBALAL SARABHAI ENTERPRISES LTD.
# 500012   ANDHRAPET         ANDHRA PETROCHEMICALS LTD.

# %%
# Pull the data for the first security
stock_data = yf.Ticker("ABB.BO")

# %%
# Extract full of the stock
stock_data_info = stock_data.info

# Extract only the important information
stock_data_info = {
    'Basic Information': {
        'symbol': stock_data_info['symbol'],
        'longName': stock_data_info['longName'],
        'currency': stock_data_info['currency'],
        'exchange': stock_data_info['exchange']
    },
    'Market Data': {
        'currentPrice': stock_data_info['currentPrice'],
        'previousClose': stock_data_info['previousClose'],
        'open': stock_data_info['open'],
        'dayLow': stock_data_info['dayLow'],
        'dayHigh': stock_data_info['dayHigh'],
        'regularMarketPreviousClose': stock_data_info['regularMarketPreviousClose'],
        'regularMarketOpen': stock_data_info['regularMarketOpen'],
        'regularMarketDayLow': stock_data_info['regularMarketDayLow'],
        'regularMarketDayHigh': stock_data_info['regularMarketDayHigh'],
        'fiftyTwoWeekLow': stock_data_info['fiftyTwoWeekLow'],
        'fiftyTwoWeekHigh': stock_data_info['fiftyTwoWeekHigh'],
        'fiftyDayAverage': stock_data_info['fiftyDayAverage'],
        'twoHundredDayAverage': stock_data_info['twoHundredDayAverage']
    },
    'Volume and Shares': {
        'volume': stock_data_info['volume'],
        'regularMarketVolume': stock_data_info['regularMarketVolume'],
        'averageVolume': stock_data_info['averageVolume'],
        'averageVolume10days': stock_data_info['averageVolume10days'],
        'averageDailyVolume10Day': stock_data_info['averageDailyVolume10Day'],
        'sharesOutstanding': stock_data_info['sharesOutstanding'],
        'impliedSharesOutstanding': stock_data_info['impliedSharesOutstanding'],
        'floatShares': stock_data_info['floatShares']
    },
    'Dividends and Yield': {
        'dividendRate': stock_data_info['dividendRate'],
        'dividendYield': stock_data_info['dividendYield'],
        'payoutRatio': stock_data_info['payoutRatio']
    },
    'Valuation and Ratios': {
        'marketCap': stock_data_info['marketCap'],
        'enterpriseValue': stock_data_info['enterpriseValue'],
        'priceToBook': stock_data_info['priceToBook'],
        'debtToEquity': stock_data_info['debtToEquity'],
        'grossMargins': stock_data_info['grossMargins'],
        'profitMargins': stock_data_info['profitMargins']
    },
    'Financial Performance': {
        'totalRevenue': stock_data_info['totalRevenue'],
        'revenuePerShare': stock_data_info['revenuePerShare'],
        'totalCash': stock_data_info['totalCash'],
        'totalCashPerShare': stock_data_info['totalCashPerShare'],
        'totalDebt': stock_data_info['totalDebt'],
        'earningsGrowth': stock_data_info['earningsGrowth'],
        'revenueGrowth': stock_data_info['revenueGrowth'],
        'returnOnAssets': stock_data_info['returnOnAssets'],
        'returnOnEquity': stock_data_info['returnOnEquity']
    },
    'Cash Flow': {
        'freeCashflow': stock_data_info['freeCashflow'],
        'operatingCashflow': stock_data_info['operatingCashflow']
    },
    'Analyst Targets': {
        'targetHighPrice': stock_data_info['targetHighPrice'],
        'targetLowPrice': stock_data_info['targetLowPrice'],
        'targetMeanPrice': stock_data_info['targetMeanPrice'],
        'targetMedianPrice': stock_data_info['targetMedianPrice']
    }
}

# %%
# View the stock info
pprint(stock_data_info)
# Out:
# {'Analyst Targets': {'targetHighPrice': 1700.0,
#                      'targetLowPrice': 942.0,
#                      'targetMeanPrice': 1305.44,
#                      'targetMedianPrice': 1381.0},
#  'Basic Information': {'currency': 'INR',
#                        'exchange': 'BSE',
#                        'longName': 'ABB India Limited',
#                        'symbol': 'ABB.BO'},
#  'Cash Flow': {'freeCashflow': 9943974912, 'operatingCashflow': 13514800128},
#  'Dividends and Yield': {'dividendRate': 23.8,
#                          'dividendYield': 0.0036000002,
#                          'payoutRatio': 0.0934},
#  'Financial Performance': {'earningsGrowth': 0.109,
#                            'returnOnAssets': 0.08698,
#                            'returnOnEquity': 0.22936001,
#                            'revenueGrowth': 0.136,
#                            'revenuePerShare': 492.973,
#                            'totalCash': 48145899520,
#                            'totalCashPerShare': 227.201,
#                            'totalDebt': 489800000,
#                            'totalRevenue': 104465203200},
#  'Market Data': {'currentPrice': 6942.3,
#                  'dayHigh': 7025.0,
#                  'dayLow': 6700.05,
#                  'fiftyDayAverage': 5992.727,
#                  'fiftyTwoWeekHigh': 7025.0,
#                  'fiftyTwoWeekLow': 3719.0,
#                  'open': 6700.05,
#                  'previousClose': 6698.75,
#                  'regularMarketDayHigh': 7025.0,
#                  'regularMarketDayLow': 6700.05,
#                  'regularMarketOpen': 6700.05,
#                  'regularMarketPreviousClose': 6698.75,
#                  'twoHundredDayAverage': 4815.3516},
#  'Valuation and Ratios': {'debtToEquity': 0.824,
#                           'enterpriseValue': 1423475474432,
#                           'grossMargins': 0.36385,
#                           'marketCap': 1471128928256,
#                           'priceToBook': 24.747349,
#                           'profitMargins': 0.1189},
#  'Volume and Shares': {'averageDailyVolume10Day': 12024,
#                        'averageVolume': 19512,
#                        'averageVolume10days': 12024,
#                        'floatShares': 52474871,
#                        'impliedSharesOutstanding': 211908000,
#                        'regularMarketVolume': 35234,
#                        'sharesOutstanding': 211908000,
#                        'volume': 35234}}

# %%
# Create dictionary for periods and intervals
periods = {
    '1d': ['1m', '2m', '5m', '15m', '30m', '60m', '90m'],
    '5d': ['1m', '2m', '5m', '15m', '30m', '60m', '90m'],
    '1mo': ['30m', '60m', '90m', '1d'],
    '3mo': ['1d', '5d', '1wk', '1mo'],
    '6mo': ['1d', '5d', '1wk', '1mo'],
    '1y': ['1d', '5d', '1wk', '1mo'],
    '2y': ['1d', '5d', '1wk', '1mo'],
    '5y': ['1d', '5d', '1wk', '1mo'],
    '10y': ['1d', '5d', '1wk', '1mo'],
    'max': ['1d', '5d', '1wk', '1mo'],
}

# %%
# Extract the data for last 1yr with 1d interval
stock_data_hist = stock_data.history(period="2y", interval="1d")
stock_data_hist
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2022-05-06 00:00:00+05:30  2151.066525  2259.265571  2146.098704  2239.394287
# 2022-05-09 00:00:00+05:30  2239.394398  2342.824535  2214.903136  2287.731445
# 2022-05-10 00:00:00+05:30  2290.165590  2290.165590  2070.736829  2215.697998
# 2022-05-11 00:00:00+05:30  2254.397617  2272.430714  2170.441425  2254.497070
# 2022-05-12 00:00:00+05:30  2245.455328  2257.079982  2207.699885  2222.653076
# ...                                ...          ...          ...          ...
# 2024-04-29 00:00:00+05:30  6476.141428  6476.141428  6327.373610  6428.711426
# 2024-04-30 00:00:00+05:30  6452.924410  6619.179980  6442.960043  6519.038086
# 2024-05-02 00:00:00+05:30  6568.162590  6723.656846  6526.661095  6655.550293
# 2024-05-03 00:00:00+05:30  6729.000000  6788.799805  6634.399902  6698.750000
# 2024-05-06 00:00:00+05:30  6700.049805  7025.000000  6700.049805  6942.299805
#
#                            Volume  Dividends  Stock Splits
# Date
# 2022-05-06 00:00:00+05:30   33316        0.0           0.0
# 2022-05-09 00:00:00+05:30   36892        0.0           0.0
# 2022-05-10 00:00:00+05:30   47545        0.0           0.0
# 2022-05-11 00:00:00+05:30   12858        0.0           0.0
# 2022-05-12 00:00:00+05:30    5914        0.0           0.0
# ...                           ...        ...           ...
# 2024-04-29 00:00:00+05:30    5564        0.0           0.0
# 2024-04-30 00:00:00+05:30    9130        0.0           0.0
# 2024-05-02 00:00:00+05:30   15550        0.0           0.0
# 2024-05-03 00:00:00+05:30    9821       23.8           0.0
# 2024-05-06 00:00:00+05:30   35234        0.0           0.0
#
# [477 rows x 7 columns]

# %%
# Clean the data for to keep only the required columns
stock_data_hist = stock_data_hist[['Close']]

# %%
# !pip install statsmodels
# !pip install matplotlib
# !pip install seaborn
# Out:
# Requirement already satisfied: statsmodels in c:\dharsh\projects\stockastic-main\stock\lib\site-packages (0.14.2)
# Requirement already satisfied: patsy>=0.5.6 in c:\dharsh\projects\stockastic-main\stock\lib\site-packages (from statsmodels) (0.5.6)
# Requirement already satisfied: numpy>=1.22.3 in c:\dharsh\projects\stockastic-main\stock\lib\site-packages (from statsmodels) (1.26.4)
# Requirement already satisfied: packaging>=21.3 in c:\dharsh\projects\stockastic-main\stock\lib\site-packages (from statsmodels) (24.0)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\dharsh\projects\stockastic-main\stock\lib\site-packages (from statsmodels) (2.2.2)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\dharsh\projects\stockastic-main\stock\lib\site-packages (from statsmodels) (1.13.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\dharsh\projects\stockastic-main\stock\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\dharsh\projects\stockastic-main\stock\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in c:\dharsh\projects\stockastic-main\stock\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: six in c:\dharsh\projects\stockastic-main\stock\lib\site-packages (from patsy>=0.5.6->statsmodels) (1.16.0)
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the 'C:\Dharsh\projects\Stockastic-main\stock\Scripts\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: matplotlib in c:\dharsh\projects\stockastic-main\stock\lib\site-packages (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\dharsh\projects\stockastic-main\stock\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\dharsh\projects\stockastic-main\stock\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\dharsh\projects\stockastic-main\stock\lib\site-packages (from matplotlib) (6.4.0)
# Requirement already satisfied: pillow>=8 in c:\dharsh\projects\stockastic-main\stock\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\dharsh\projects\stockastic-main\stock\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: packaging>=20.0 in c:\dharsh\projects\stockastic-main\stock\lib\site-packages (from matplotlib) (24.0)
# Requirement already satisfied: cycler>=0.10 in c:\dharsh\projects\stockastic-main\stock\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: numpy>=1.21 in c:\dharsh\projects\stockastic-main\stock\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\dharsh\projects\stockastic-main\stock\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: fonttools>=4.22.0 in c:\dharsh\projects\stockastic-main\stock\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\dharsh\projects\stockastic-main\stock\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.18.1)
# Requirement already satisfied: six>=1.5 in c:\dharsh\projects\stockastic-main\stock\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the 'C:\Dharsh\projects\Stockastic-main\stock\Scripts\python.exe -m pip install --upgrade pip' command.
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#      -------------------------------------- 294.9/294.9 KB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.2 in c:\dharsh\projects\stockastic-main\stock\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\dharsh\projects\stockastic-main\stock\lib\site-packages (from seaborn) (3.8.4)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\dharsh\projects\stockastic-main\stock\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: cycler>=0.10 in c:\dharsh\projects\stockastic-main\stock\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: packaging>=20.0 in c:\dharsh\projects\stockastic-main\stock\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\dharsh\projects\stockastic-main\stock\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\dharsh\projects\stockastic-main\stock\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\dharsh\projects\stockastic-main\stock\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\dharsh\projects\stockastic-main\stock\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.51.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\dharsh\projects\stockastic-main\stock\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.4.0)
# Requirement already satisfied: pillow>=8 in c:\dharsh\projects\stockastic-main\stock\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\dharsh\projects\stockastic-main\stock\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: pytz>=2020.1 in c:\dharsh\projects\stockastic-main\stock\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\dharsh\projects\stockastic-main\stock\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\dharsh\projects\stockastic-main\stock\lib\site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.18.1)
# Requirement already satisfied: six>=1.5 in c:\dharsh\projects\stockastic-main\stock\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the 'C:\Dharsh\projects\Stockastic-main\stock\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
# Imports
import datetime as dt

#Statsmodels is a great library we can use to run regressions
import statsmodels.api as sm

# Import matplotlib for plotting
import matplotlib.pyplot as plt

# Seaborn extends the capabilities of Matplotlib
import seaborn as sns
sns.set_style("darkgrid")

# %%
# Change frequency to day
stock_data_hist = stock_data_hist.asfreq('D', method='ffill')

# %%
# Fill missing values
stock_data_hist = stock_data_hist.fillna(method='ffill')

# %%
# View the new data
stock_data_hist
# Out:
#                                  Close
# Date
# 2022-05-06 00:00:00+05:30  2239.394287
# 2022-05-07 00:00:00+05:30  2239.394287
# 2022-05-08 00:00:00+05:30  2239.394287
# 2022-05-09 00:00:00+05:30  2287.731445
# 2022-05-10 00:00:00+05:30  2215.697998
# ...                                ...
# 2024-05-02 00:00:00+05:30  6655.550293
# 2024-05-03 00:00:00+05:30  6698.750000
# 2024-05-04 00:00:00+05:30  6698.750000
# 2024-05-05 00:00:00+05:30  6698.750000
# 2024-05-06 00:00:00+05:30  6942.299805
#
# [732 rows x 1 columns]

# %%
# Import the required libraries
from statsmodels.tsa.ar_model import AutoReg

# Define training and testing area
train_df = stock_data_hist.iloc[:int(len(stock_data_hist) * 0.9) + 1] # 90%
test_df = stock_data_hist.iloc[int(len(stock_data_hist) * 0.9):] # 10%

# %%
# Define training model
model = AutoReg(train_df['Close'], 250).fit(cov_type="HC0")

# %%
# Predict data for test data
predictions = model.predict(start=test_df.index[0], end=test_df.index[-1], dynamic=True)

# Predict 90 days into the future
forecast = model.predict(start=test_df.index[0], end=test_df.index[-1]+dt.timedelta(days=90), dynamic=True)

# View the forecasted values
forecast
# Out:
# 2024-02-23 00:00:00+05:30    5382.112617
# 2024-02-24 00:00:00+05:30    5392.658747
# 2024-02-25 00:00:00+05:30    5585.258565
# 2024-02-26 00:00:00+05:30    5621.573296
# 2024-02-27 00:00:00+05:30    5706.961570
#                                 ...
# 2024-07-31 00:00:00+05:30    5828.311925
# 2024-08-01 00:00:00+05:30    5819.676530
# 2024-08-02 00:00:00+05:30    5788.196768
# 2024-08-03 00:00:00+05:30    5972.332217
# 2024-08-04 00:00:00+05:30    5925.581815
# Freq: D, Length: 164, dtype: float64

# %%
# Set style for seaborn plot
sns.set_style('darkgrid')

# Add automatic datetime converters
pd.plotting.register_matplotlib_converters()

# Default figure size
sns.mpl.rc('figure',figsize=(6, 5))

# Set fig and ax
fig, ax = plt.subplots()

# Plot the data
ax = train_df.tail(5).plot(ax=ax, color='blue')
ax = test_df.plot(ax=ax, color='orange')
ax = forecast.plot(ax=ax, color='green')
ax = predictions.plot(ax=ax, color='red')

# Customize the plot
plt.legend(["Train Data", "Test Data", "Forecast", "Predictions"])
plt.title("Stock Price Data")

# Show the plot
plt.show()
